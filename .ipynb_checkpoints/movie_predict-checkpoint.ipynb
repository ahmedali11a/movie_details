# %% [markdown]
# # Importing Libraries and Setting Up Environment

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import category_encoders as ce
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import r2_score , mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression  
from sklearn.ensemble import GradientBoostingRegressor ,RandomForestRegressor
from sklearn.model_selection import cross_val_score ,  GridSearchCV ,train_test_split ,ParameterGrid
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
companies = pd.read_csv("companies.csv")
countries = pd.read_csv("countries.csv")
genres = pd.read_csv("genres.csv")   
langs = pd.read_csv("langs.csv")
movie_details = pd.read_csv("movie_details.csv")

# %% [markdown]
# # Rename column

# %%
companies=companies.rename(columns={"country": "country_of_company"})

# %% [markdown]
# # Merge datasets

# %%
movie_details = pd.merge(movie_details, companies, left_on="id", right_on="movie_id", how="left")
movie_details.drop(columns=["movie_id"], inplace=True)

movie_details = pd.merge(movie_details, countries, left_on="id", right_on="movie_id", how="left")
movie_details.drop(columns=["movie_id"], inplace=True)

movie_details = pd.merge(movie_details, genres, left_on="id", right_on="movie_id", how="left")
movie_details.drop(columns=["movie_id"], inplace=True)

movie_details = pd.merge(movie_details, langs, left_on="id", right_on="movie_id", how="left")
movie_details.drop(columns=["movie_id"], inplace=True)

# %%
df=movie_details

# %% [markdown]
# # number of rows and columns

# %%
df.shape
# Out:
# (64876, 26)

# %% [markdown]
# # Columns in dataset

# %%
df.columns.tolist()
# Out:
# ['adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'budget',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'release_date',
#  'revenue',
#  'runtime',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'company_name',
#  'country_of_company',
#  'country',
#  'genre',
#  'lang']

# %% [markdown]
# # Print first 5 rows

# %%
df.head()
# Out:
#    adult                     backdrop_path      belongs_to_collection  \
# 0  False  /9mJ9dxCGpudxyBtlC0M9Y4pTyXN.jpg  The Wild Robot Collection
# 1  False  /9mJ9dxCGpudxyBtlC0M9Y4pTyXN.jpg  The Wild Robot Collection
# 2  False  /9mJ9dxCGpudxyBtlC0M9Y4pTyXN.jpg  The Wild Robot Collection
# 3  False  /9mJ9dxCGpudxyBtlC0M9Y4pTyXN.jpg  The Wild Robot Collection
# 4  False  /au3o84ub27qTZiMiEc9UYzN74V3.jpg                      False
#
#      budget                           homepage       id     imdb_id  \
# 0  78000000  https://www.thewildrobotmovie.com  1184918  tt29623480
# 1  78000000  https://www.thewildrobotmovie.com  1184918  tt29623480
# 2  78000000  https://www.thewildrobotmovie.com  1184918  tt29623480
# 3  78000000  https://www.thewildrobotmovie.com  1184918  tt29623480
# 4  18000000     https://www.elevationmovie.com  1035048  tt23558280
#
#   original_language  original_title  \
# 0                en  The Wild Robot
# 1                en  The Wild Robot
# 2                en  The Wild Robot
# 3                en  The Wild Robot
# 4                en       Elevation
#
#                                             overview  ...  \
# 0  After a shipwreck, an intelligent robot called...  ...
# 1  After a shipwreck, an intelligent robot called...  ...
# 2  After a shipwreck, an intelligent robot called...  ...
# 3  After a shipwreck, an intelligent robot called...  ...
# 4  A single father and two women venture from the...  ...
#
#                           tagline           title  video  vote_average  \
# 0      Discover your true nature.  The Wild Robot  False          8.36
# 1      Discover your true nature.  The Wild Robot  False          8.36
# 2      Discover your true nature.  The Wild Robot  False          8.36
# 3      Discover your true nature.  The Wild Robot  False          8.36
# 4  Don't go down without a fight.       Elevation  False          6.30
#
#    vote_count          company_name country_of_company country  \
# 0        4117  DreamWorks Animation                 US      US
# 1        4117  DreamWorks Animation                 US      US
# 2        4117  DreamWorks Animation                 US      US
# 3        4117  DreamWorks Animation                 US      US
# 4         376         Lyrical Media                 US      US
#
#              genre     lang
# 0        Animation  English
# 1           Action  English
# 2  Science Fiction  English
# 3           Family  English
# 4           Action  English
#
# [5 rows x 26 columns]

# %% [markdown]
# # Make genres for each movie in one cell

# %%
df['genre'] = df['genre'].fillna("")
df = df.groupby("id").agg({
    'company_name': 'first',
    'adult': 'first',
    'backdrop_path': 'first',
    'budget': 'first',
    'homepage': 'first',
    'imdb_id': 'first',
    'original_language': 'first',
    'original_title': 'first',
    'overview': 'first',
    'popularity': 'first',
    'poster_path': 'first',
    'release_date': 'first',
    'revenue': 'first',
    'runtime': 'first',
    'status': 'first',
    'tagline': 'first',
    'video': 'first',
    'vote_average': 'first',
    'vote_count': 'first',
    'country': 'first',
    'belongs_to_collection' : 'first',
    'country_of_company' : 'first',
    'title' :'first',
    'lang' : 'first',
    'genre': lambda x: ','.join(x.unique())
}).reset_index()

# %% [markdown]
# # Number of rows and columns after combine genres in one cell

# %%
df.shape
# Out:
# (2988, 26)

# %% [markdown]
# # print first 10 rows

# %%
df.head(10)
# Out:
#    id          company_name  adult                     backdrop_path  \
# 0  11        Lucasfilm Ltd.  False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg
# 1  12                 Pixar  False  /eCynaAOgYYiw5yN5lBwz3IxqvaW.jpg
# 2  13    Paramount Pictures  False  /mzfx54nfDPTUXZOG48u4LaEheDy.jpg
# 3  14   DreamWorks Pictures  False   /DztBnZaqmla2sGUW9s8AyOmskT.jpg
# 4  15   Mercury Productions  False  /ruF3Lmd4A8MHbnEBE6lxPMbsHGL.jpg
# 5  18               Gaumont  False  /wgvc3PmjQGtYYDWaeuV867mnFDs.jpg
# 6  19                   UFA  False  /eeMoFKxjjiCi6iep2GEZtSAMYIr.jpg
# 7  22  Walt Disney Pictures  False  /wW7Wt5bXzPy4VOEE4LTIUDyDgBo.jpg
# 8  24               Miramax  False  /p3WiF8qYS7Qp17YRYgrFh7gf9P9.jpg
# 9  27      Revolution Films  False  /qU7tNIMpRqkizIObXfkJY3haTqh.jpg
#
#       budget                                           homepage    imdb_id  \
# 0   11000000  http://www.starwars.com/films/star-wars-episod...  tt0076759
# 1   94000000              http://movies.disney.com/finding-nemo  tt0266543
# 2   55000000  https://www.paramountmovies.com/movies/forrest...  tt0109830
# 3   15000000                                               None  tt0169547
# 4     839727                                               None  tt0033467
# 5   90000000  https://www.sonypictures.com/movies/thefifthel...  tt0119116
# 6    5300000                                               None  tt0017136
# 7  140000000  https://movies.disney.com/pirates-of-the-carib...  tt0325980
# 8   30000000    http://www.miramax.com/movie/kill-bill-volume-1  tt0266697
# 9    1000000                                               None  tt0411705
#
#   original_language                                     original_title  \
# 0                en                                          Star Wars
# 1                en                                       Finding Nemo
# 2                en                                       Forrest Gump
# 3                en                                    American Beauty
# 4                en                                       Citizen Kane
# 5                fr                               Le Cinquième Élément
# 6                de                                         Metropolis
# 7                en  Pirates of the Caribbean: The Curse of the Bla...
# 8                en                                  Kill Bill: Vol. 1
# 9                en                                            9 Songs
#
#                                             overview  ...  \
# 0  Princess Leia is captured and held hostage by ...  ...
# 1  Nemo, an adventurous young clownfish, is unexp...  ...
# 2  A man with a low IQ has accomplished great thi...  ...
# 3  Lester Burnham, a depressed suburban father in...  ...
# 4  Newspaper magnate Charles Foster Kane is taken...  ...
# 5  In 2257, a taxi driver is unintentionally give...  ...
# 6  In a futuristic city sharply divided between t...  ...
# 7  After Port Royal is attacked and pillaged by a...  ...
# 8  An assassin is shot by her ruthless employer, ...  ...
# 9  Matt, a young glaciologist, soars across the v...  ...
#
#                                              tagline  video vote_average  \
# 0       A long time ago in a galaxy far, far away...  False        8.204
# 1  There are 3.7 trillion fish in the ocean. They...  False        7.800
# 2  The world will never be the same once you've s...  False        8.500
# 3                                       Look closer.  False        8.000
# 4  Some called him a hero...others called him a h...  False        8.000
# 5                     There is no future without it.  False        7.555
# 6  There can be no understanding between the hand...  False        8.114
# 7              Prepare to be blown out of the water.  False        7.800
# 8                      A roaring rampage of revenge.  False        8.000
# 9  2 lovers, one summer, and the 9 songs that def...  False        5.600
#
#    vote_count  country                belongs_to_collection  \
# 0       20817       US                 Star Wars Collection
# 1       19388       US              Finding Nemo Collection
# 2       27752       US                                False
# 3       12128       US                                False
# 4        5566       US                                False
# 5       10824       FR                                False
# 6        2792       DE                                False
# 7       20809       US  Pirates of the Caribbean Collection
# 8       17552       US                 Kill Bill Collection
# 9         518       US                                False
#
#   country_of_company                                              title  \
# 0                 US                                          Star Wars
# 1                 US                                       Finding Nemo
# 2                 US                                       Forrest Gump
# 3                 US                                    American Beauty
# 4                 US                                       Citizen Kane
# 5                 FR                                  The Fifth Element
# 6                 DE                                         Metropolis
# 7                 US  Pirates of the Caribbean: The Curse of the Bla...
# 8                 US                                  Kill Bill: Vol. 1
# 9                 GB                                            9 Songs
#
#           lang                             genre
# 0      English  Adventure,Action,Science Fiction
# 1      English                  Animation,Family
# 2      English              Comedy,Drama,Romance
# 3      English                             Drama
# 4      English                     Mystery,Drama
# 5      English  Science Fiction,Action,Adventure
# 6  No Language             Drama,Science Fiction
# 7      English          Adventure,Fantasy,Action
# 8      English                      Action,Crime
# 9      English               Drama,Music,Romance
#
# [10 rows x 26 columns]

# %% [markdown]
# # Number of unique values in each column

# %%
for col in df.columns:
    if col != 'genre':
        print(col, ":", df[col].nunique())
# Out:
# id : 2988
# company_name : 1341
# adult : 1
# backdrop_path : 2950
# budget : 358
# homepage : 1760
# imdb_id : 2939
# original_language : 42
# original_title : 2937
# overview : 2967
# popularity : 2910
# poster_path : 2985
# release_date : 2260
# revenue : 2055
# runtime : 181
# status : 4
# tagline : 2416
# video : 1
# vote_average : 1257
# vote_count : 2171
# country : 56
# belongs_to_collection : 585
# country_of_company : 53
# title : 2924
# lang : 61

# %% [markdown]
# # Drop some column

# %%
drop_cols = [
    'id' ,
    'imdb_id' ,
    'adult' ,
    'video' ,
    'homepage' ,
    'poster_path',
    'backdrop_path' ,
    'title' ,
    'original_title' ,
    'overview' ,
    'tagline' ,
    'status' ,
    'lang'
]

df.drop(columns=drop_cols, axis=1 , inplace=True)

# %% [markdown]
# # Print first 5 rows

# %%
df.head()
# Out:
#           company_name    budget original_language  popularity release_date  \
# 0       Lucasfilm Ltd.  11000000                en     106.348   1977-05-25
# 1                Pixar  94000000                en     125.133   2003-05-30
# 2   Paramount Pictures  55000000                en     105.101   1994-06-23
# 3  DreamWorks Pictures  15000000                en      44.255   1999-09-15
# 4  Mercury Productions    839727                en      37.402   1941-04-17
#
#      revenue  runtime  vote_average  vote_count country  \
# 0  775398007      121         8.204       20817      US
# 1  940335536      100         7.800       19388      US
# 2  677387716      142         8.500       27752      US
# 3  356296601      122         8.000       12128      US
# 4   23218000      119         8.000        5566      US
#
#      belongs_to_collection country_of_company  \
# 0     Star Wars Collection                 US
# 1  Finding Nemo Collection                 US
# 2                    False                 US
# 3                    False                 US
# 4                    False                 US
#
#                               genre
# 0  Adventure,Action,Science Fiction
# 1                  Animation,Family
# 2              Comedy,Drama,Romance
# 3                             Drama
# 4                     Mystery,Drama

# %% [markdown]
# # Information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2988 entries, 0 to 2987
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   company_name           2898 non-null   object
#  1   budget                 2988 non-null   int64
#  2   original_language      2988 non-null   object
#  3   popularity             2988 non-null   float64
#  4   release_date           2980 non-null   object
#  5   revenue                2988 non-null   int64
#  6   runtime                2988 non-null   int64
#  7   vote_average           2988 non-null   float64
#  8   vote_count             2988 non-null   int64
#  9   country                2988 non-null   object
#  10  belongs_to_collection  2988 non-null   object
#  11  country_of_company     2818 non-null   object
#  12  genre                  2988 non-null   object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 303.6+ KB

# %% [markdown]
# # Convert datatype of release_date to datetime

# %%
df['release_date']=pd.to_datetime(df['release_date'])

# %% [markdown]
# # Encode belongs_to_collection to (1,0)

# %%
df['belongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: 0 if x =='False' else 1)

# %% [markdown]
# # print first 5 rows

# %%
df.head()
# Out:
#           company_name    budget original_language  popularity release_date  \
# 0       Lucasfilm Ltd.  11000000                en     106.348   1977-05-25
# 1                Pixar  94000000                en     125.133   2003-05-30
# 2   Paramount Pictures  55000000                en     105.101   1994-06-23
# 3  DreamWorks Pictures  15000000                en      44.255   1999-09-15
# 4  Mercury Productions    839727                en      37.402   1941-04-17
#
#      revenue  runtime  vote_average  vote_count country  \
# 0  775398007      121         8.204       20817      US
# 1  940335536      100         7.800       19388      US
# 2  677387716      142         8.500       27752      US
# 3  356296601      122         8.000       12128      US
# 4   23218000      119         8.000        5566      US
#
#    belongs_to_collection country_of_company                             genre
# 0                      1                 US  Adventure,Action,Science Fiction
# 1                      1                 US                  Animation,Family
# 2                      0                 US              Comedy,Drama,Romance
# 3                      0                 US                             Drama
# 4                      0                 US                     Mystery,Drama

# %% [markdown]
# # Describe data

# %%
df.describe(include='all')
# Out:
#               company_name        budget original_language   popularity  \
# count                 2898  2.988000e+03              2988  2988.000000
# unique                1341           NaN                42          NaN
# top     Paramount Pictures           NaN                en          NaN
# freq                    95           NaN              2322          NaN
# mean                   NaN  4.088657e+07               NaN    71.187226
# min                    NaN  0.000000e+00               NaN    31.375000
# 25%                    NaN  0.000000e+00               NaN    37.820000
# 50%                    NaN  1.500000e+07               NaN    48.579000
# 75%                    NaN  6.000000e+07               NaN    72.310000
# max                    NaN  4.600000e+08               NaN   877.206000
# std                    NaN  5.977487e+07               NaN    75.558031
#
#                          release_date       revenue      runtime  \
# count                            2980  2.988000e+03  2988.000000
# unique                            NaN           NaN          NaN
# top                               NaN           NaN          NaN
# freq                              NaN           NaN          NaN
# mean    2012-06-12 06:24:38.657718016  1.490740e+08   106.056225
# min               1922-02-16 00:00:00  0.000000e+00     0.000000
# 25%               2006-08-02 18:00:00  0.000000e+00    93.000000
# 50%               2016-07-28 12:00:00  4.027773e+07   105.000000
# 75%               2023-07-14 00:00:00  1.942677e+08   121.000000
# max               2027-05-05 00:00:00  2.923706e+09   700.000000
# std                               NaN  2.567133e+08    31.439701
#
#         vote_average    vote_count country  belongs_to_collection  \
# count    2988.000000   2988.000000    2988            2988.000000
# unique           NaN           NaN      56                    NaN
# top              NaN           NaN      US                    NaN
# freq             NaN           NaN    2001                    NaN
# mean        6.625673   3906.435074     NaN               0.379518
# min         0.000000      0.000000     NaN               0.000000
# 25%         6.200000    244.000000     NaN               0.000000
# 50%         6.800000   2146.500000     NaN               0.000000
# 75%         7.380000   5647.500000     NaN               1.000000
# max        10.000000  36930.000000     NaN               1.000000
# std         1.336313   5007.203140     NaN               0.485348
#
#        country_of_company  genre
# count                2818   2988
# unique                 53   1004
# top                    US  Drama
# freq                 1961    115
# mean                  NaN    NaN
# min                   NaN    NaN
# 25%                   NaN    NaN
# 50%                   NaN    NaN
# 75%                   NaN    NaN
# max                   NaN    NaN
# std                   NaN    NaN

# %%
categorical_cols=df.select_dtypes(include=['object']).columns
numeric_cols=df.select_dtypes(include=['int' ,'float']).columns

# %% [markdown]
# # Handle Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # check if the data is null and count the number of nulls

# %%
df.isnull().sum()
# Out:
# company_name              90
# budget                     0
# original_language          0
# popularity                 0
# release_date               8
# revenue                    0
# runtime                    0
# vote_average               0
# vote_count                 0
# country                    0
# belongs_to_collection      0
# country_of_company       170
# genre                      0
# dtype: int64

# %% [markdown]
# # Handle nulls

# %%
df['country_of_company']=df['country_of_company'].fillna(df['country'])

# %%
df['company_name']=df['company_name'].fillna(df.groupby('country_of_company')['company_name'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.nan))

# %%
df.dropna(subset=['release_date','company_name'] , inplace=True)

# %%
df.isnull().sum()
# Out:
# company_name             0
# budget                   0
# original_language        0
# popularity               0
# release_date             0
# revenue                  0
# runtime                  0
# vote_average             0
# vote_count               0
# country                  0
# belongs_to_collection    0
# country_of_company       0
# genre                    0
# dtype: int64

# %% [markdown]
# # split release_date to (release_year,release_month,release_day)

# %%
df['release_year'] = df['release_date'].dt.year
df['release_month'] = df['release_date'].dt.month
df['release_day'] = df['release_date'].dt.day

df.drop('release_date' , axis=1 , inplace=True)

# %%
for col in df.columns:
    print(col , df[col].unique())
# Out:
# company_name ['Lucasfilm Ltd.' 'Pixar' 'Paramount Pictures' ... 'Moboreels'
#  'Señor Mono' 'ReelShort']
# budget [ 11000000  94000000  55000000  15000000    839727  90000000   5300000
#  140000000  30000000   1000000  31500000  14400000  75000000  20000000
#  200000000  12000000  29000000  41000000   5000000 132000000  70000000
#    2500000   9000000  28000000  18000000   6000000  48000000 103000000
#   16000000   1900000  19000000  10000000         0  25000000  14000000
#  150000000  93000000  79000000  23500000  14600000   4500000   1448864
#   17000000   5700000  45000000   4000000 185000000  85000000 110000000
#   40000000  35000000   8000000   1200000 102000000   2200000  65000000
#   72000000  16400000   6400000   2883848  13000000  54000000  22000000
#    3000000   7000000 207000000 300000000    878000  80000000  12500000
#   63000000   2000000   1800000    397751    200000  49000000   1488423
#  180000000 100000000 125000000  59000000   2479000   4650000  58000000
#   14500000   9500000  60000000  42000000  50000000     17300    806947
#   23000000 139000000 258000000 105000000  52000000 115000000   3300000
#   10500000   2777000 175000000   1750000  92000000 130000000  18500000
#   13500000  34000000  32000000    400000    350000   3500000 250000000
#   36000000   3200000  33000000 160000000    150000  68000000   5800000
#   46000000 120000000  26000000    600000    325000    100000  24000000
#   44000000  31000000 223000000  66000000   3180000 126000000    900000
#    4800000  98000000 145000000  57000000 379000000  32350000 113000000
#  137000000 215000000 155000000  51000000  51500000 225000000  27000000
#      60000  47000000  58500000  37000000  71000000    858000  21000000
#   43000000  38000000    550000 165000000   1400000  61000000   1500000
#    3700000 123000000  11500000    500000  64000000   5500000  82000000
#    1100000  95000000  53000000  17500000   6500000  84000000  76000000
#   62000000  12600000 128000000  56000000 133000000  11800000   2800000
#     830000 127500000 109000000   3800000   2600000   4200000    160000
#    2900000    812000 149000000  10000005  10800000   3600000   7500000
#   12850990   1207520   8200000   8500000   1250000   6900000    825000
#     125000  13200000  23600000 237000000  69000000 170000000   2100000
#     215000   8240000 220000000   2700000    140000   6000200 135000000
#  142000000 117000000 260000000    275000 144000000 209000000   6800000
#    2400000   1255000 190000000   6200000  32500000 460000000 176000000
#  195000000    230758 400000000   1344000 210000000 365000000    175000
#   78000000  39200000  97000000 178000000 245000000  73000000 230000000
#  129000000 127000000 416000000  58800000  81000000  74000000     50000
#   99000000  19800000  25130430  50100000  88000000   2300000 108000000
#    8575000  10951000 356000000 152000000   9900000    750000 294700000
#  116000000 217000000 177200000  22500000 104000000  97600000 111000000
#   60720000 340000000  18300000 159000000  19500000  28210303 146000000
#      35000 183000000  39000000 297000000  24350000   5900000 151000000
#   11363000  86000000  15600000   8819200  50300000   5740000    126580
#  205000000 291000000   8020000  25600000   8400000   9100000  24500000
#  274800000   1522860   6300000   1203235   7600000   8300000   1242172
#   15700000 388369742    250000 118000000  14750000  17739525  67000000
#   30069500   6700000   9600000  22800000  73800000  83000000  15900000
#        119   6042800  36150000  65500000  38400000  23900000  13272819
#   15200000  22700000    120000     10000   4920000  37315205  38500000
#     963703   8800000  26885000   6600000      8500      5000   1480000
#    6790000  23200000  35954590  53400000   4400000   4350000   1303000
#    5400000  12460000    148000   3467987   5270000  27200000    800000
#      30000]
# original_language ['en' 'fr' 'de' 'ja' 'zh' 'it' 'pt' 'ko' 'cn' 'es' 'th' 'hi' 'ru' 'sv'
#  'lt' 'el' 'sr' 'nl' 'id' 'da' 'te' 'uk' 'no' 'tr' 'pl' 'vi' 'lv' 'fi'
#  'tl' 'ta' 'ml' 'mn' 'bn' 'cs' 'hu' 'ms' 'fa' 'ca' 'ga' 'zu' 'xx']
# popularity [106.348 125.133 105.101 ...  62.209  71.004  37.911]
# revenue [775398007 940335536 677387716 ...  22881613     51860   4150341]
# runtime [121 100 142 122 119 126 148 143 111  69 147 130  87 108 151 149 129 132
#  110 117 106 101 113 118 115 127 155 114 116 107 103  98 169 120 179 201
#  134 125 133 124 131 102 152 105 145 154 137 177 128  93  89 175 202 162
#   99 187  86 140 109 178 229 138 166 159 207  91  97 136  83 150 195  81
#  161 139  94 135 189  24  85 112 181  92 194  88 123 141 146 163  95 222
#  157 183 144  84 153 233  90 104 228 170 197  96 165 185 199  70  77  82
#  156 220 158 251  78  80  79  76 180  75  74  64  72 174  60  54  45  43
#  190 171  68  48  22  71  63  51  50  55  61  58  41 192   7  67  38   6
#   13   0  19  14  46 188  23 164  25  31 209   3  28 206 215  15 167  10
#   52 242 176 173 226 182 700  27  11   9  40  59  30  73  49   5  66  44
#   65]
# vote_average [8.204 7.8   8.5   ... 6.762 7.625 6.313]
# vote_count [20817 19388 27752 ...   125    80   147]
# country ['US' 'FR' 'DE' 'GB' 'JP' 'HK' 'IT' 'CA' 'BR' 'NZ' 'KR' 'MX' 'CN' 'AU'
#  'ES' 'ZA' 'TH' 'DK' 'IN' 'CL' 'SU' 'AR' 'SE' 'NL' 'GR' 'AE' 'HU' 'RU'
#  'RS' 'ID' 'CO' 'BG' 'AT' 'CZ' 'UA' 'MW' 'TW' 'CY' 'NO' 'TR' 'CI' 'PL'
#  'VN' 'LV' 'FI' 'PH' 'BE' 'MN' 'IE' 'MY' 'DO' 'PY' 'NG']
# belongs_to_collection [1 0]
# country_of_company ['US' 'FR' 'DE' 'GB' 'HK' 'JP' 'IT' 'PL' 'CA' 'BR' 'KR' 'MX' 'ES' 'CZ'
#  'CH' 'NZ' 'ZA' 'AU' 'TH' 'DK' 'IN' 'CL' 'SU' 'BG' 'NL' 'GR' 'HU' 'RU'
#  'RS' 'CO' 'SE' 'AR' 'AT' 'CN' 'BE' 'FI' 'UA' 'TW' 'PT' 'NO' 'ID' 'TR'
#  'IS' 'VN' 'LV' 'PH' 'AE' 'MN' 'LU' 'BD' 'MY' 'IE' 'DO' 'NG' 'UY']
# genre ['Adventure,Action,Science Fiction' 'Animation,Family'
#  'Comedy,Drama,Romance' ... 'Science Fiction,Adventure,Comedy,Family'
#  'Documentary,Crime' 'TV Movie,Documentary']
# release_year [1977 2003 1994 1999 1941 1997 1927 2004 1979 1992 2007 2006 1968 1995
#  2002 2000 1998 2005 1996 1982 1981 1984 1987 1989 1976 1985 1993 1983
#  1990 2001 1930 1988 2008 1961 1971 2014 1986 1972 1959 1974 1973 1935
#  1991 1943 1954 1957 1964 1938 1958 1966 1975 2009 1960 1978 1939 1962
#  1922 1963 1965 1967 1980 1946 2011 2012 1942 2013 2024 1956 2010 1970
#  1955 1953 1940 1950 1951 1949 2020 2016 2017 2022 2015 2025 2019 2018
#  2023 2021 2026 2027]
# release_month [ 5  6  9  4  2  7 10  8  3 12 11  1]
# release_day [25 30 23 15 17  2  6  9 10 16 19  7 29  8 28  1 13 27 11 12 21 24  4 14
#   3 18 20 22 31 26  5]

# %% [markdown]
# # Calculate mean of revenue

# %%
mean_revenue = df['revenue'].mean()

# %% [markdown]
# # visualization

# %%
yearly_revenue = df.groupby(df['release_year'])['revenue'].sum()

plt.figure(figsize=(10, 6))
plt.plot(yearly_revenue.index, yearly_revenue.values, marker='o')
plt.title('Total Revenue per Year')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.grid(True)
plt.savefig('Total_Revenue_per_Year.png')
plt.show()

# %%
yearly_revenue = df.groupby(df['release_month'])['revenue'].sum()

plt.figure(figsize=(10, 6))
plt.plot(yearly_revenue.index, yearly_revenue.values, marker='o')
plt.title('Total Revenue per Month')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.grid(True)
plt.savefig('Total_Revenue_per_Month.png')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='country', order=df['country'].value_counts().index)
plt.title('Number of Movies per Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.savefig('Number_of_Movies_per_Country.png')
plt.show()

# %%
df['company_name'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Companies by Movie Count")
plt.xlabel("Company Name")
plt.ylabel("Number of Movies")
plt.tight_layout()
plt.savefig("Top_10_Companies_by_Movie_Count.png")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='budget', y='revenue')
plt.title('Budget vs Revenue')
plt.savefig('Budget_vs_Revenue.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='original_language', order=df['original_language'].value_counts().index)
plt.title('Number of Movies per Language')
plt.xticks(rotation=90)
plt.savefig('Number_of_Movies_per_Language.png')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='popularity', y='revenue')
plt.title('Popularity vs Revenue')
plt.savefig('Popularity_vs_Revenue.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
movies_per_year = df.groupby(df['release_year']).size()
plt.plot(movies_per_year.index, movies_per_year.values, marker='o')
plt.title('Number of Movies per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.savefig('Number_of_Movies_per_Year.png')
plt.show()

# %%
counts = df['belongs_to_collection'].value_counts()

labels = ['No Collection', 'Collection']

plt.figure(figsize=(6,6))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title("Movies with/without Collection")
plt.savefig("Pie_chart_collection.png")
plt.show()

# %%
plt.figure(figsize=(12,6))
avg_revenue_country = df.groupby('country')['revenue'].mean().sort_values(ascending=False).head(15)
sns.barplot(x=avg_revenue_country.index, y=avg_revenue_country.values)
plt.title('Average Revenue per Country (Top 15)')
plt.xticks(rotation=90)
plt.savefig('Average_Revenue_per_Country_(Top 15).png')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(data=df, x='belongs_to_collection', y='revenue')
plt.title('Average Revenue: Collection vs Non-Collection')
plt.xticks([0,1], ['No Collection', 'In Collection'])
plt.savefig('Average_Revenue_Collection_vs_Non-Collection.png')
plt.show()

# %%
for col in ['budget','popularity' ,'revenue' , 'runtime' , 'vote_average' , 'vote_count']:
    sns.histplot(df[col], bins=10, kde=True)
    plt.title(f"Histogram of {col} with Density Curve")
    plt.savefig(f'Histogram_{col}.png')
    plt.show()

# %%
for col in ['budget','popularity' ,'revenue' , 'runtime' , 'vote_average' , 'vote_count']:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df, y=col)
    plt.title(f'{col}', fontsize=14)
    plt.tight_layout()
    plt.savefig(f'boxplot_{col}.png')
    plt.show()

# %%
df.columns
# Out:
# Index(['company_name', 'budget', 'original_language', 'popularity', 'revenue',
#        'runtime', 'vote_average', 'vote_count', 'country',
#        'belongs_to_collection', 'country_of_company', 'genre', 'release_year',
#        'release_month', 'release_day'],
#       dtype='object')

# %% [markdown]
# # Handle outliers

# %%
cols = ['budget','popularity','revenue','runtime','vote_average','vote_count']

for col in cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df[col] = df[col].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %% [markdown]
# # make target enconding

# %%
categorical_cols = ['company_name', 'original_language', 'country' , 'country_of_company']

encoder = ce.TargetEncoder(cols=categorical_cols)

df_encoded = encoder.fit_transform(df[categorical_cols], df['revenue'])


df[categorical_cols] = df_encoded

df.head()
# Out:
#    company_name      budget  original_language  popularity      revenue  \
# 0  2.300751e+08  11000000.0       1.504500e+08    106.3480  488250000.0
# 1  2.534977e+08  94000000.0       1.504500e+08    124.2585  488250000.0
# 2  1.857424e+08  55000000.0       1.504500e+08    105.1010  488250000.0
# 3  1.562948e+08  15000000.0       1.504500e+08     44.2550  356296601.0
# 4  1.087500e+08    839727.0       1.504500e+08     37.4020   23218000.0
#
#    runtime  vote_average  vote_count       country  belongs_to_collection  \
# 0    121.0         8.204     13767.0  1.579761e+08                      1
# 1    100.0         7.800     13767.0  1.579761e+08                      1
# 2    142.0         8.500     13767.0  1.579761e+08                      0
# 3    122.0         8.000     12128.0  1.579761e+08                      0
# 4    119.0         8.000      5566.0  1.579761e+08                      0
#
#    country_of_company                             genre  release_year  \
# 0        1.624391e+08  Adventure,Action,Science Fiction          1977
# 1        1.624391e+08                  Animation,Family          2003
# 2        1.624391e+08              Comedy,Drama,Romance          1994
# 3        1.624391e+08                             Drama          1999
# 4        1.624391e+08                     Mystery,Drama          1941
#
#    release_month  release_day
# 0              5           25
# 1              5           30
# 2              6           23
# 3              9           15
# 4              4           17

# %% [markdown]
# # convert genres to genres_count

# %%
df['genres_split'] = df['genre'].str.split(',')

df['genre_count'] = df['genres_split'].str.len()

df.drop(['genres_split','genre'],axis=1 , inplace=True)

df.head()
# Out:
#    company_name      budget  original_language  popularity      revenue  \
# 0  2.300751e+08  11000000.0       1.504500e+08    106.3480  488250000.0
# 1  2.534977e+08  94000000.0       1.504500e+08    124.2585  488250000.0
# 2  1.857424e+08  55000000.0       1.504500e+08    105.1010  488250000.0
# 3  1.562948e+08  15000000.0       1.504500e+08     44.2550  356296601.0
# 4  1.087500e+08    839727.0       1.504500e+08     37.4020   23218000.0
#
#    runtime  vote_average  vote_count       country  belongs_to_collection  \
# 0    121.0         8.204     13767.0  1.579761e+08                      1
# 1    100.0         7.800     13767.0  1.579761e+08                      1
# 2    142.0         8.500     13767.0  1.579761e+08                      0
# 3    122.0         8.000     12128.0  1.579761e+08                      0
# 4    119.0         8.000      5566.0  1.579761e+08                      0
#
#    country_of_company  release_year  release_month  release_day  genre_count
# 0        1.624391e+08          1977              5           25            3
# 1        1.624391e+08          2003              5           30            2
# 2        1.624391e+08          1994              6           23            3
# 3        1.624391e+08          1999              9           15            1
# 4        1.624391e+08          1941              4           17            2

# %% [markdown]
# # handle e in numeric columns

# %%
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    df[col] = df[col].apply(lambda x: int(round(x)) if pd.notnull(x) else x)

# %%
df.head()
# Out:
#    company_name    budget  original_language  popularity    revenue  runtime  \
# 0     230075066  11000000          150450019         106  488250000      121
# 1     253497748  94000000          150450019         124  488250000      100
# 2     185742413  55000000          150450019         105  488250000      142
# 3     156294784  15000000          150450019          44  356296601      122
# 4     108749955    839727          150450019          37   23218000      119
#
#    vote_average  vote_count    country  belongs_to_collection  \
# 0             8       13767  157976093                      1
# 1             8       13767  157976093                      1
# 2             8       13767  157976093                      0
# 3             8       12128  157976093                      0
# 4             8        5566  157976093                      0
#
#    country_of_company  release_year  release_month  release_day  genre_count
# 0           162439080          1977              5           25            3
# 1           162439080          2003              5           30            2
# 2           162439080          1994              6           23            3
# 3           162439080          1999              9           15            1
# 4           162439080          1941              4           17            2

# %% [markdown]
# # Correlation Heatmap of Features

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr() , annot=True , fmt='.2f')
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# # Dropping Features with Low Correlation to Target

# %%
df.drop(['release_day','release_month'] , axis=1 , inplace=True)

# %%
df.columns
# Out:
# Index(['company_name', 'budget', 'original_language', 'popularity', 'revenue',
#        'runtime', 'vote_average', 'vote_count', 'country',
#        'belongs_to_collection', 'country_of_company', 'release_year',
#        'genre_count'],
#       dtype='object')

# %% [markdown]
# # split data into features and target

# %%
x = df.drop('revenue',axis=1)
y=df['revenue']

# %% [markdown]
# # split data into train and test

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=.25,random_state=42)

# %% [markdown]
# # Scaling Features Using StandardScaler

# %%
scale_cols = ['company_name', 'country', 'budget', 'vote_average', 'vote_count','country_of_company','original_language' , 'popularity','release_year' , 'genre_count']


scaler = StandardScaler()
x_train[scale_cols] = scaler.fit_transform(x_train[scale_cols])
x_test[scale_cols] = scaler.transform(x_test[scale_cols])

# %% [markdown]
# # LinearRegression model

# %%
results_models=[]

le = LinearRegression()

le.fit(x_train, y_train)


y_train_pred = le.predict(x_train)
y_test_pred = le.predict(x_test)

print(f"Train: {r2_score(y_train, y_train_pred):.4f}")
print(f"Test : {r2_score(y_test, y_test_pred):.4f}")

cv_scores = cross_val_score(le, x_train, y_train, cv=5, scoring='r2')
print("Cross-Validation Scores (5-Fold):", cv_scores)
print(f"Cross-Validation Accuracy (5-Fold): {cv_scores.mean():.4f}")

print(f"Train RMSE: {np.sqrt(mean_squared_error(y_train, y_train_pred)):.4f}")
print(f"Test  RMSE: {np.sqrt(mean_squared_error(y_test, y_test_pred)):.4f}")

train_rmse_percentage = ( np.sqrt(mean_squared_error(y_train, y_train_pred))/ mean_revenue) * 100
test_rmse_percentage  = (np.sqrt(mean_squared_error(y_test, y_test_pred))  / mean_revenue) * 100

print(f"Train RMSE (% of mean revenue): {train_rmse_percentage:.2f}%")
print(f"Test  RMSE (% of mean revenue): {test_rmse_percentage:.2f}%")

results_models.append({
    "Model": "Linear Regression",
    "Train": r2_score(y_train, y_train_pred),
    "Test": r2_score(y_test, y_test_pred),
    "Train RMSE": np.sqrt(mean_squared_error(y_train, y_train_pred)),
    "Test RMSE": np.sqrt(mean_squared_error(y_test, y_test_pred)),
    "Train RMSE (%)": train_rmse_percentage,
    "Test RMSE (%)": test_rmse_percentage
})
# Out:
# Train: 0.7661
# Test : 0.7859
# Cross-Validation Scores (5-Fold): [0.75136308 0.76223719 0.79431498 0.71344328 0.79755946]
# Cross-Validation Accuracy (5-Fold): 0.7638
# Train RMSE: 77492223.1669
# Test  RMSE: 72496117.9365
# Train RMSE (% of mean revenue): 51.79%
# Test  RMSE (% of mean revenue): 48.45%

# %% [markdown]
# # PolynomialRegression model

# %%
poly_2 =PolynomialFeatures(degree=2)

x_train_poly=poly_2.fit_transform(x_train)
x_test_poly=poly_2.transform(x_test)

le2 = LinearRegression()

le2.fit(x_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = le2.predict(x_train_poly)
print(f"train: {r2_score(y_train , y_train_pred):.4f}")
y_test_pred = le2.predict(x_test_poly)
print(f"test: {r2_score(y_test , y_test_pred):.4f}")

cv_scores = cross_val_score(le2, x_train, y_train, cv=5, scoring='r2')
print("Cross-Validation Scores (5-Fold):", cv_scores)
print(f"Cross-Validation Accuracy (5-Fold): {cv_scores.mean():.4f}")

print(f"Train RMSE: {np.sqrt(mean_squared_error(y_train, y_train_pred)):.4f}")
print(f"Test  RMSE: {np.sqrt(mean_squared_error(y_test, y_test_pred)):.4f}")

train_rmse_percentage = ( np.sqrt(mean_squared_error(y_train, y_train_pred))/ mean_revenue) * 100
test_rmse_percentage  = (np.sqrt(mean_squared_error(y_test, y_test_pred))  / mean_revenue) * 100

print(f"Train RMSE (% of mean revenue): {train_rmse_percentage:.2f}%")
print(f"Test  RMSE (% of mean revenue): {test_rmse_percentage:.2f}%")

results_models.append({
    "Model": "Polynomial Regression (deg=2)",
    "Train": r2_score(y_train, y_train_pred),
    "Test": r2_score(y_test, y_test_pred),
    "Train RMSE": np.sqrt(mean_squared_error(y_train, y_train_pred)),
    "Test RMSE": np.sqrt(mean_squared_error(y_test, y_test_pred)),
    "Train RMSE (%)": train_rmse_percentage,
    "Test RMSE (%)": test_rmse_percentage
})
# Out:
# train: 0.8158
# test: 0.8020
# Cross-Validation Scores (5-Fold): [0.75136308 0.76223719 0.79431498 0.71344328 0.79755946]
# Cross-Validation Accuracy (5-Fold): 0.7638
# Train RMSE: 68774742.8618
# Test  RMSE: 69723362.4791
# Train RMSE (% of mean revenue): 45.96%
# Test  RMSE (% of mean revenue): 46.60%

# %% [markdown]
# # RandomForest model

# %%
rf = RandomForestRegressor(
    n_estimators=200,   
    max_depth=5,      
    min_samples_split=2, 
    min_samples_leaf=1,  
    random_state=0
)

rf.fit(x_train, y_train)

y_train_pred = rf.predict(x_train)
y_test_pred = rf.predict(x_test)

print(f"Train: {r2_score(y_train, y_train_pred):.4f}")
print(f"Test : {r2_score(y_test, y_test_pred):.4f}")

cv_scores = cross_val_score(rf, x_train, y_train, cv=5, scoring='r2')
print("Cross-Validation Scores (5-Fold):", cv_scores)
print(f"Cross-Validation Accuracy (5-Fold): {cv_scores.mean():.4f}")

print(f"Train RMSE: {np.sqrt(mean_squared_error(y_train, y_train_pred)):.4f}")
print(f"Test  RMSE: {np.sqrt(mean_squared_error(y_test, y_test_pred)):.4f}")

train_rmse_percentage = ( np.sqrt(mean_squared_error(y_train, y_train_pred))/ mean_revenue) * 100
test_rmse_percentage  = (np.sqrt(mean_squared_error(y_test, y_test_pred))  / mean_revenue) * 100

print(f"Train RMSE (% of mean revenue): {train_rmse_percentage:.2f}%")
print(f"Test  RMSE (% of mean revenue): {test_rmse_percentage:.2f}%")

results_models.append({
    "Model": "Random Forest",
    "Train": r2_score(y_train, y_train_pred),
    "Test": r2_score(y_test, y_test_pred),
   "Train RMSE": np.sqrt(mean_squared_error(y_train, y_train_pred)),
    "Test RMSE": np.sqrt(mean_squared_error(y_test, y_test_pred)),
    "Train RMSE (%)": train_rmse_percentage,
    "Test RMSE (%)": test_rmse_percentage
})
# Out:
# Train: 0.8575
# Test : 0.8169
# Cross-Validation Scores (5-Fold): [0.79010062 0.81982331 0.83674187 0.76033823 0.84548642]
# Cross-Validation Accuracy (5-Fold): 0.8105
# Train RMSE: 60491384.3659
# Test  RMSE: 67053723.1282
# Train RMSE (% of mean revenue): 40.43%
# Test  RMSE (% of mean revenue): 44.81%

# %% [markdown]
# # GradientBoosting model with grid search

# %%
param_grid = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 5, 7],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2]
}

results = []

for params in ParameterGrid(param_grid):
    gbr = GradientBoostingRegressor(**params, random_state=0)
    gbr.fit(x_train, y_train)

    y_train_pred = gbr.predict(x_train)
    y_test_pred = gbr.predict(x_test)

    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

    train_rmse_pct = (train_rmse / mean_revenue) * 100
    test_rmse_pct  = (test_rmse / mean_revenue) * 100

    results.append({
        "params": params,
        "Train": train_r2,
        "Test": test_r2,
        "Train RMSE": train_rmse,
        "Test RMSE": test_rmse,
        "Train RMSE (%)": train_rmse_pct,
        "Test RMSE (%)": test_rmse_pct,
        "(Train-Test)": abs(train_r2 - test_r2)
    })

df_results = pd.DataFrame(results)
df_results = df_results.sort_values(
    by=["Test", "(Train-Test)", "Train"],
    ascending=[False, True, False]
)

for i in range(5):
    best = df_results.iloc[i]
    print(f"Row {i+1}")
    print("Best Parameters:", best["params"])
    print("Train:", best["Train"])
    print("Test:", best["Test"])
    print("Train RMSE:", best["Train RMSE"])
    print("Test RMSE:", best["Test RMSE"])
    print("Train RMSE (%):", best["Train RMSE (%)"])
    print("Test RMSE (%):", best["Test RMSE (%)"])
    print("|Train - Test|:", best["(Train-Test)"])
    if i != 4:
        print("=" * 40)

best_model = df_results.iloc[0]
best_params = best_model["params"]

gbr_best = GradientBoostingRegressor(**best_params, random_state=0)
gbr_best.fit(x_train, y_train)

y_train_pred = gbr_best.predict(x_train)
y_test_pred = gbr_best.predict(x_test)

train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
test_rmse  = np.sqrt(mean_squared_error(y_test, y_test_pred))

train_rmse_percentage = (train_rmse / mean_revenue) * 100
test_rmse_percentage  = (test_rmse / mean_revenue) * 100

results_models.append({
    "Model": "Gradient Boosting",
    "Train": r2_score(y_train, y_train_pred),
    "Test": r2_score(y_test, y_test_pred),
    "Train RMSE": train_rmse,
    "Test RMSE": test_rmse,
    "Train RMSE (%)": train_rmse_percentage,
    "Test RMSE (%)": test_rmse_percentage
})
# Out:
# Row 1
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Train: 0.9186895638649571
# Test: 0.8387368857397584
# Train RMSE: 45692281.63079832
# Test RMSE: 62920387.51535497
# Train RMSE (%): 30.537895089670698
# Test RMSE (%): 42.05209554801925
# |Train - Test|: 0.0799526781251988
# ========================================
# Row 2
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Train: 0.918783110640533
# Test: 0.8381753031808062
# Train RMSE: 45665989.82909952
# Test RMSE: 63029849.25805563
# Train RMSE (%): 30.52032327549683
# Test RMSE (%): 42.12525300690771
# |Train - Test|: 0.08060780745972673
# ========================================
# Row 3
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Train: 0.9187361616473922
# Test: 0.8378735336469394
# Train RMSE: 45679186.97632181
# Test RMSE: 63088590.69105292
# Train RMSE (%): 30.529143432489942
# Test RMSE (%): 42.16451214771366
# |Train - Test|: 0.08086262800045285
# ========================================
# Row 4
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Train: 0.8913442787894119
# Test: 0.8370969011972629
# Train RMSE: 52819708.377193846
# Test RMSE: 63239516.418805525
# Train RMSE (%): 35.30142631359695
# Test RMSE (%): 42.26538156976796
# |Train - Test|: 0.05424737759214904
# ========================================
# Row 5
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Train: 0.8916592264498544
# Test: 0.8367036784702219
# Train RMSE: 52743101.66150227
# Test RMSE: 63315795.590205975
# Train RMSE (%): 35.25022712276081
# Test RMSE (%): 42.31636185025769
# |Train - Test|: 0.054955547979632535

# %% [markdown]
# # DecisionTree model

# %%
dt = DecisionTreeRegressor(
    max_depth=5, 
    min_samples_split=2, 
    min_samples_leaf=1, 
    random_state=0
)

dt.fit(x_train, y_train)

y_train_pred_dt = dt.predict(x_train)
y_test_pred_dt = dt.predict(x_test)

print(f"Train: {r2_score(y_train, y_train_pred_dt):.4f}")
print(f"Test : {r2_score(y_test, y_test_pred_dt):.4f}")

cv_scores= cross_val_score(dt, x_train, y_train, cv=5, scoring='r2')
print("Cross-Validation Scores (5-Fold):", cv_scores)
print(f"Cross-Validation Accuracy (5-Fold): {cv_scores.mean():.4f}")

print(f"Train RMSE: {np.sqrt(mean_squared_error(y_train, y_train_pred_dt)):.4f}")
print(f"Test  RMSE: {np.sqrt(mean_squared_error(y_test, y_test_pred_dt)):.4f}")

train_rmse_percentage = ( np.sqrt(mean_squared_error(y_train, y_train_pred_dt))/ mean_revenue) * 100
test_rmse_percentage  = (np.sqrt(mean_squared_error(y_test, y_test_pred_dt))  / mean_revenue) * 100

print(f"Train RMSE (% of mean revenue): {train_rmse_percentage:.2f}%")
print(f"Test  RMSE (% of mean revenue): {test_rmse_percentage:.2f}%")

results_models.append({
    "Model": "Decision Tree",
    "Train": r2_score(y_train, y_train_pred_dt),
    "Test": r2_score(y_test, y_test_pred_dt),
    "Train RMSE": np.sqrt(mean_squared_error(y_train, y_train_pred_dt)),
    "Test RMSE": np.sqrt(mean_squared_error(y_test, y_test_pred_dt)),
    "Train RMSE (%)": train_rmse_percentage,
    "Test RMSE (%)": test_rmse_percentage
})
# Out:
# Train: 0.8291
# Test : 0.7811
# Cross-Validation Scores (5-Fold): [0.73758514 0.74778153 0.78711431 0.73914558 0.80724861]
# Cross-Validation Accuracy (5-Fold): 0.7638
# Train RMSE: 66248152.6013
# Test  RMSE: 73303056.1104
# Train RMSE (% of mean revenue): 44.28%
# Test  RMSE (% of mean revenue): 48.99%

# %% [markdown]
# # Compare between models

# %%
df_models = pd.DataFrame(results_models)
print(df_models)
# Out:
#                            Model     Train      Test    Train RMSE  \
# 0              Linear Regression  0.766129  0.785917  7.749222e+07
# 1  Polynomial Regression (deg=2)  0.815788  0.801980  6.877474e+07
# 2                  Random Forest  0.857489  0.816854  6.049138e+07
# 3              Gradient Boosting  0.918690  0.838737  4.569228e+07
# 4                  Decision Tree  0.829074  0.781125  6.624815e+07
#
#       Test RMSE  Train RMSE (%)  Test RMSE (%)
# 0  7.249612e+07       51.791009      48.451922
# 1  6.972336e+07       45.964785      46.598783
# 2  6.705372e+07       40.428700      44.814561
# 3  6.292039e+07       30.537895      42.052096
# 4  7.330306e+07       44.276168      48.991229

# %%
df_models.plot(
    x="Model",
    y=["Train", "Test"],
    kind="bar",
    figsize=(10,6)
)
plt.title("Model Performance (R² Score)")
plt.ylabel("R²")
plt.xticks(rotation=90)
plt.legend(title="Dataset")
plt.savefig("compare_between_models.png")
plt.show()

# %% [markdown]
# ### Overall Model Performance: All models show relatively high R² scores, indicating that they explain a significant portion of the variance in the target variable. Test scores range from around 0.78 to 0.84, reflecting good predictive performance.
#
# ## Comparison Across Models:
#
# ### Linear Regression has the lowest training and testing R², suggesting it is the least effective among the tested models.
#
# ### Polynomial Regression (degree=2) and Random Forest perform moderately well, with training R² slightly higher than testing, indicating some minor overfitting.
#
# ### Gradient Boosting and Decision Tree achieve the highest training R² (≈0.92) and strong test R² (≈0.84), suggesting they capture patterns in the data effectively, although the gap between training and testing indicates slight overfitting.
#
# ### Overfitting Considerations: Models like Gradient Boosting and Decision Tree exhibit higher training than testing R², signaling mild overfitting. Models with smaller gaps, like Linear and Ridge Regression, generalize better but may underfit slightly.

# %% [markdown]
# # Deployment

# %%
import joblib

file='ValueClassifier'
joblib.dump(rf , "ValueClassifier")
model = joblib.load(open("ValueClassifier",'rb'))
joblib.dump(encoder , "encode")
encod = joblib.load(open("encode", 'rb'))
joblib.dump(scaler , "scaler")
scal = joblib.load(open("scaler", 'rb'))

outlier_bounds = {}
for col in ['budget','popularity','revenue','runtime','vote_average','vote_count']:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_bounds[col] = (lower_bound, upper_bound)

joblib.dump(outlier_bounds, 'outlier_bounds')
outlier_bounds = joblib.load(open("outlier_bounds", 'rb'))
